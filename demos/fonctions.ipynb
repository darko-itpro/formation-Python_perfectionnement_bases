# %% [markdown]
# # Les fonctions, rappels…

# %%
def truc():
    return 42

# %%
value = truc

# %%
value()
# Out:
# 42

# %%
i = 10

# %%
print(i)
# Out:
# 10

# %%
print = 20

# %%
print(i)
# Out:
# 10

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 del print
#
# NameError: name 'print' is not defined
