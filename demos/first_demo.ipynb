# %% [markdown]
# # Rappels Données Variables

# %%
camelot = ["Arthur", "Merlin"]

# %%
kingdom = camelot

# %%
id(camelot)

# %%
id(kingdom)

# %%
id(kingdom) == id(camelot)

# %%
kingdom is camelot

# %%
def func():
    global i
    i = i + 2
    print(i)

i = 10

func()
# Out:
# 12

# %%
print(i)
# Out:
# 12
