# %% [markdown]
# # Plein de choses sur les variables
#
# ## Données mutables, données immuables

# %%
camelot = ["Arthur", "Merlin", "Lancelot"]

# %%
camelot[1] = "Tim"

# %%
camelot

# %%
camelot = ("Arthur", "Merlin", "Lancelot")

# %%
camelot[1] = "Tim"

# %% [markdown]
# ## Références vers les données

# %%
kingdom = None

# %%
camelot = ["Arthur", "Merlin", "Lancelot"]

# %%
kingdom = camelot

# %%
camelot.append("Robin")

# %%
camelot

# %%
kingdom

# %%
print(id(camelot) == id(kingdom))

# %%
camelot[:]

# %%
camelot = ["Arthur", "Merlin", ["Lancelot"]]

# %%
kingdom = camelot.copy()

# %%
kingdom is camelot

# %%
kingdom[0] = "Pendragon"

# %%
kingdom

# %%
camelot

# %%
camelot[2].append("Robin")

# %%
camelot

# %%
kingdom

# %%
help(list.copy)

# %% [markdown]
# ## Visibilité des variables

# %%
def func():
    global i
    i = i + 1
    print(i)

i = 20

func()
# Out:
# 42

# %%
i
# Out:
# 42

# %% [markdown]
# ## Idiome Python

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
