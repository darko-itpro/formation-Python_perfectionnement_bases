# %% [markdown]
# # Rappel sur l'approche fonctionnelle

# %%
def func():
    return 42

# %%
value = func

# %%
value
# Out:
# <function __main__.func()>

# %%
del func

# %%
# %whos
# Out:
# Variable                        Type        Data/Info
# -----------------------------------------------------
# pydev_jupyter_vars              module      <module 'pydev_jupyter_va<...>g/pydev_jupyter_vars.py'>
# remove_imported_pydev_package   function    <function remove_imported<...>v_package at 0x105ab0b80>
# sys                             module      <module 'sys' (built-in)>

# %%
i = 10

# %%
print(i)
# Out:
# 10

# %%
print = 42

# %%
print(42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(42)
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print(i)
# Out:
# 10

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 del print
#
# NameError: name 'print' is not defined

# %% [markdown]
# ##

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
for i in (len(name) for name in camelot):
    print(i)
# Out:
# 6
# 6
# 8
# 5
# 8
# 7

# %%
[len(name) for name in camelot]
# Out:
# [6, 6, 8, 5, 8, 7]

# %%
def func(kingdom):
    for name in kingdom:
        yield name.upper()

    print("Done")

# %%
func(camelot)
# Out:
# <generator object func at 0x1062c2740>

# %%
for name in func(camelot):
    print(name)
# Out:
# ARTHUR
# MERLIN
# LANCELOT
# ROBIN
# PERCEVAL
# KARADOC
# Done

# %%
def file_parser():
    with open("myfile") as my_file:
        for line in my_file:
            yield transform_line(line)
