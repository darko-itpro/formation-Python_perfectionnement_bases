# %% [markdown]
# # Rappels fonctions

# %% [markdown]
# ## Données immuables
# Tuples ou N-uplets

# %%
v = 1, 2, 3

# %%
type(v)

# %%
v = 2,

# %%
type(v)

# %%
def myfunc():
    return 1, 2, 3

# %%
camelot = ["Arthur", "Merlin"]

# %%
king = camelot[0]
wizard = camelot[1]

# %%
king, wizard = ["Arthur", "Merlin"]

# %%
king

# %%
question = 42
answer = "Meaning of life"

# %%
question, answer = answer, question

# %%
question

# %% [markdown]
# ## Variables et données

# %%
id(question)

# %%
camelot

# %%
id(camelot)

# %%
kingdom = ["Arthur", "Merlin"]

# %%
id(kingdom)

# %%
k = camelot

# %%
id(k) == id(camelot)

# %%
k is camelot

# %%
a = 1
if a is True:
    print("Oui")

# %% [markdown]
# ## Fonctions

# %%
i = 10

def func():
    global i
    i = i + 20
    print(i)


func()
print(i)
# Out:
# 30
# 30

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %% [markdown]
# # Références

# %%
def truc():
    return 42

# %%
value = truc
value()
# Out:
# 42

# %%
i = 10

# %%
i = 10
print(i)
# Out:
# 10

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(i)
#
# TypeError: 'int' object is not callable

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 del print
#
# NameError: name 'print' is not defined

# %%
print(i)
# Out:
# 10

# %%
truc
# Out:
# <function __main__.truc()>

# %%
tstamp = 789
hours, minutes = divmod(tstamp, 60)
# Out:
# (13, 9)

# %%
"Il est {}h{:02}".format(*divmod(tstamp, 60))
# Out:
# 'Il est 13h09'

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]
king, wizard, *knights = camelot

# %%
knights
# Out:
# []

# %%
def func(*args):
    print(args)

# %%
func()
# Out:
# ()

# %%
func(1, 8)
# Out:
# (1, 8)

# %%
func(value=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 func(value=10)
#
# TypeError: func() got an unexpected keyword argument 'value'

# %%
def func(**kwargs):
    print(kwargs)

# %%
func()
# Out:
# {}

# %%
func(value=1)
# Out:
# {'value': 1}
