# %% [markdown]
# # Rappels Données Variables

# %%
camelot = ["Arthur", "Merlin"]

# %%
kingdom = camelot

# %%
id(camelot)

# %%
id(kingdom)

# %%
id(kingdom) == id(camelot)

# %%
kingdom is camelot

# %%
def func():
    global i
    i = i + 2
    print(i)

i = 10

func()
# Out:
# 12

# %%
print(i)
# Out:
# 12

# %% [markdown]
# # Les paramètres optionnels

# %%
def create_account(my_id, value: int = 100, overdraft: bool = False):
    print(my_id, value, overdraft)

# %%
create_account("Mi Id", overdraft=True)
# Out:
# Mi Id 100 True

# %% [markdown]
# # Idiome comportement fonctions

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
