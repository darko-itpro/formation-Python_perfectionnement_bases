# %%
class WhatEver:

    __slots__ = ("answer")

    def __init__(self):
        self.answer = 42
#        self.question = "meaning of life"

# %%
c = WhatEver()

# %%
c.question = ""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 c.question = ""
#
# AttributeError: 'WhatEver' object has no attribute 'question' and no __dict__ for setting new attributes

# %%
c.answer
# Out:
# 42
