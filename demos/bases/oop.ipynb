# %%
class MyClass:
    def __init__(self):
        self.my_attr = 42

    def my_method(self):
        print(f"My method with {self.my_attr}")

    def __str__(self):
        return "from str"

    def __repr__(self):
        return "from repr"

# %%
mc = MyClass()

# %%
print(mc)
# Out:
# from str

# %%
mc
# Out:
# from repr

# %%
mc.my_method
# Out:
# <bound method MyClass.my_method of <__main__.MyClass object at 0x10ad3a270>>

# %%
MyClass.my_method(mc)
# Out:
# My method with 42

# %%
mc.my_method()
# Out:
# My method with 42

# %%
class Something:
    def __init__(self):
        self.my_attr = "Something attr"

    def my_method(self):
        return self.my_attr.upper()

# %%
s.my_method()
# Out:
# 'SOMETHING ATTR'

# %%
MyClass.my_method(s)
# Out:
# My method with Something attr

# %%
dir(mc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'my_attr',
#  'my_method']

# %%
print(mc)
# Out:
# from str

# %%
def get_value(self):
    return self._myattr

def set_value(something, what):
    something._myattr = what

# %%
class MyClass:
    def __init__(self):
        self._myattr = 42

    myattr = property(get_value)

# %%
c = MyClass()
c.myattr = 54

# %%
c.myattr
# Out:
# 54

# %%
class MyClass:
    def __init__(self):
        self._myattr = 42

    @property
    def myattr(self):
        return self._myattr

    @myattr.setter
    def myattr(self, what):
        self._myattr = what
