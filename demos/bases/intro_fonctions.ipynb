# %% [markdown]
# # Intro aux fonctions

# %%
def func():
    return 42

# %%
value = func

# %%
value()
# Out:
# 42

# %% [markdown]
# ## Paramètres

# %%
def create_account(my_id, /, value:int=100, *, overdraft:boolean=False):
    print(my_id, value, overdraft)

# %%
create_account("mi id", 500, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 create_account("mi id", 500, True)
#
# TypeError: create_account() takes from 1 to 2 positional arguments but 3 were given

# %%
create_account("mi id", value=500, overdraft=True)
# Out:
# mi id 500 True
