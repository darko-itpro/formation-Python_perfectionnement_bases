# %% [markdown]
# # Generalities

# %%
camelot = ["Arthur", "Merlin", "Lancelot"]

# %%
kingdom = camelot

# %%
id(camelot) == id(kingdom)
# Out:
# True

# %%
camelot is kingdom
# Out:
# True

# %%
camelot[1] = "Tim"

# %%
camelot[0][0] = "p"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 camelot[0][0] = "p"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Functions

# %%
i = 10

def myfunc():
    global i
    i = i + 2
    print(i)

myfunc()
# Out:
# 12

# %%
i
# Out:
# 12
