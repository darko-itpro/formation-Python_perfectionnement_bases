# %% [markdown]
# # Generalities

# %%
camelot = ["Arthur", "Merlin", "Lancelot"]

# %%
kingdom = camelot

# %%
id(camelot) == id(kingdom)
# Out:
# True

# %%
camelot is kingdom
# Out:
# True

# %%
camelot[1] = "Tim"

# %%
camelot[0][0] = "p"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 camelot[0][0] = "p"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Functions

# %%
i = 10

def myfunc():
    global i
    i = i + 2
    print(i)

myfunc()
# Out:
# 12

# %%
i
# Out:
# 12

# %% [markdown]
# # Optional parameters

# %%
def say_hello(name:str = "World"):
    print(f"Hello {name}")

# %%
say_hello("Melin")
say_hello()
# Out:
# Hello Melin
# Hello World

# %%
def create_account(id:str, /, value:float=100, *, overdraft:bool = False):
    print(id, value, overdraft)

# %%
create_account("My id", 10000000, True)
create_account("My id", value=10000000)
create_account("My id")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 create_account("My id", 10000000, True)
#       2 create_account("My id", value=10000000)
#       3 create_account("My id")
#
# TypeError: create_account() takes from 1 to 2 positional arguments but 3 were given

# %%
create_account("My id", overdraft=True)
# Out:
# My id 100 True

# %%
create_account(id="My Id")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 create_account(id="My Id")
#
# TypeError: create_account() got some positional-only arguments passed as keyword arguments: 'id'

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[0:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[2:4]
# Out:
# ['Lancelot', 'Robin']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", 'Bohort', "Robin", "Perceval", "Karadoc"]

# %%
start = 0
step = 2

while group := camelot[start:start+step]:
    print(group)
    start = start + step
# Out:
# ['Arthur', 'Merlin']
# ['Lancelot', 'Bohort']
# ['Robin', 'Perceval']
# ['Karadoc']

# %%
camelot[2:4] = ("Conan", "John Snow")

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Conan', 'John Snow', 'Karadoc']

# %%
camelot[2:5] = ["Lancelot"]

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Perceval', 'Karadoc']

# %%
value = 1, 2, 3,
type(value)
# Out:
# tuple

# %%
camelot = ["Arthur", "Merlin"]

# %%
king, wizard = ["Arthur", "Merlin"]

# %%
king
# Out:
# 'Arthur'

# %%
question = 42
answer = "Meaning of life"

# %%
(answer, question) = (question, answer)

# %%
answer
# Out:
# 42
