# %% [markdown]
# # Fonctions

# %%
def create_account(myid:str, /, value:float=100, *,  overdraft:bool=False):
    print(myid, value, overdraft)

# %%
create_account("My id", 100, True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 create_account("My id", 100, True)
#
# TypeError: create_account() takes from 1 to 2 positional arguments but 3 were given

# %%
create_account("my id", overdraft=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 create_account(myid="my id", overdraft=True)
#
# TypeError: create_account() got some positional-only arguments passed as keyword arguments: 'myid'

# %% [markdown]
# ## Approche fonctionnelle

# %%
def func():
    return 42

# %%
value = func

# %%
value
# Out:
# <function __main__.func()>

# %%
value()
# Out:
# 42

# %%
func
# Out:
# <function __main__.func()>

# %%
i = 42

# %%
i()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 i()
#
# TypeError: 'int' object is not callable

# %%
i = 10

# %%
print(i)
# Out:
# 10

# %%
print = 20

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(i)
#
# TypeError: 'int' object is not callable

# %%
del print

# %%
print(i)
# Out:
# 10

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 del print
#
# NameError: name 'print' is not defined

# %% [markdown]
# ## Unpack

# %%
timestamp = 563

"{}h{:02}".format(*divmod(563, 60))
# Out:
# '9h23'

# %%
hour, minutes = divmod(563, 60)

# %%
hour
# Out:
# 9

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin"]

# %%
king, wizard, *knights = camelot

# %%
knights
# Out:
# ['Lancelot', 'Robin']

# %%
def func(*args):
    print(args)

# %%
func(toto="ii")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 func(toto="ii")
#
# TypeError: func() got an unexpected keyword argument 'toto'

# %%
def func(**kwargs):
    print(kwargs)

# %%
func()
# Out:
# {}

# %%
func(king="Arthur")
# Out:
# {'king': 'Arthur'}

# %%
func(42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 func(42)
#
# TypeError: func() takes 0 positional arguments but 1 was given

# %%
camelot = {"king": "Arthur", "wizard": "Merlin"}

# %%
def create_kingdom(king, wizard, *knights):
    print(king, wizard, knights)

# %%
create_kingdom(king="Arthur", wizard="Merlin")
# Out:
# Arthur Merlin ()

# %%
create_kingdom(**camelot)
# Out:
# Arthur Merlin ()
