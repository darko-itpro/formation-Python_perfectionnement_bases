# %%
from pathlib import Path

# %%
Path('.')
# Out:
# PosixPath('.')

# %%
file_path = Path('.')

# %%
root_path = file_path.resolve().parent

# %%
root_path / "exercices"
# Out:
# PosixPath('/Users/dad3zero/formation/241125-python_perf/formation-Python_perfectionnement_bases/exercices')

# %%
file_path = root_path.joinpath("exercices", "exo_02.py")

# %%
file_path.exists()
# Out:
# True

# %%
file_path.is_file()
# Out:
# True

# %%
open(file_path)
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/formation/241125-python_perf/formation-Python_perfectionnement_bases/exercices/exo_02.py' mode='r' encoding='UTF-8'>

# %%
file_path
# Out:
# PosixPath('/Users/dad3zero/formation/241125-python_perf/formation-Python_perfectionnement_bases/exercices/exo_02.py')

# %%
print(file_path)
# Out:
# /Users/dad3zero/formation/241125-python_perf/formation-Python_perfectionnement_bases/exercices/exo_02.py
