# %% [markdown]
# # variables et valeurs

# %%
42 + 2

# %%
camelot = ["Arthur", "Lancelot"]

# %%
camelot.append("Robin")

# %%
camelot

# %%
camelot = ("Arthur", "Lancelot")

# %%
camelot.append("Robin")

# %%
camelot = ["Arthur", "Lancelot"]
camelot.append("Robin")
camelot

# %%
camelot = ["Arthur", "Lancelot"]
camelot = camelot + ["Robin"]
camelot

# %%
camelot = ("Arthur", "Lancelot")
kingdom = camelot

# %%
camelot.append("Robin")

# %%
kingdom

# %%
id(kingdom) == id(camelot)

# %%
def func():
    global i
    i = i + 1
    print(i)
    
i = 20

func()
print(f"{i=}")
# Out:
# 21
# i=21

# %%
def create_account(myid:str, /, *, value: float=100,overdraft:bool=False):
    print(myid, value, overdraft)

# %%
create_account("My Id", value=50, overdraft=True)
# Out:
# My Id 50 True

# %%
def func(myid, *args):
    print(myid, args)

# %%
func("my id")
# Out:
# my id ()

# %%
func(myid="my id", toto=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 func(myid="my id", toto=10)
#
# TypeError: func() got an unexpected keyword argument 'toto'

# %%
def func(myid, **kwargs):
    print(myid, kwargs)

# %%
func("muy", toto=10)
# Out:
# muy {'toto': 10}
