# %% [markdown]
# # POO

# %%
class Training:
    def __init__(self, subject: str, duration: int, seats: int = 12):
        self.subject: str = subject.title()
        self.duration = duration
        self.seats = seats
        self.students = []

    def has_seats_left(self):
        return self.seats - len(self.students) > 0

# %%
t = Training("Python", 5)

# %%
t.has_seats_left()
# Out:
# True

# %%
t.has_seats_left
# Out:
# <bound method Training.has_seats_left of <__main__.Training object at 0x107bf9be0>>

# %%
Training.has_seats_left(t)
# Out:
# True

# %%
t.has_seats_left()
# Out:
# True

# %%
class Truk:
    def __init__(self):
        self.seats = 42
        self.students = ()

# %%
tr = Truk()

# %%
Training.has_seats_left(tr)
# Out:
# True
