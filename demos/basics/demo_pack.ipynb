# %%
def func(*args):
    print(args)

# %%
func()
func(1)
func(1, 2)
# Out:
# ()
# (1,)
# (1, 2)

# %%
def funk(**kwargs):
    print(kwargs)

# %%
funk()
funk(name="toto", age=10)
# Out:
# {}
# {'name': 'toto', 'age': 10}

# %%
func(*(2, 3, 4))
# Out:
# (2, 3, 4)

# %%
funk(**{"name":"Toto", "age":10})
# Out:
# {'name': 'Toto', 'age': 10}

# %%
def create_account(id, value=100, overdraft=False):
    pass

def superfunk(*args, **kargs):
    pass
