# %%
def counter(name):
    count = 0
    def inner():
        nonlocal count
        print("Calling ", name)
        count += 1

    def get_count():
        return count

    inner.get_count = get_count

    return inner

# %%
c = counter("my counter")

# %%
c()
# Out:
# Calling  my counter

# %%
c()
# Out:
# Calling  my counter

# %%
c.get_count()
# Out:
# 2
