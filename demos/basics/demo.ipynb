# %% [markdown]
# # Les bases

# %%
camelot = ["Arthur", "Merlin"]

# %%
kingdom = ("Arthur", "Merlin")

# %%
camelot[1] = "Tim"

# %%
kingdom[1] = "Tim"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 kingdom[1] = "Tim"
#
# TypeError: 'tuple' object does not support item assignment

# %%
value = 1,

# %%
type(value)
# Out:
# tuple

# %%
value
# Out:
# (1,)

# %%
def truc():
    return 1, 2, 3

# %%
question = 42
answer = "meaning of life"

# %%
question, answer = answer, question

# %%
question, answer = "meaning of life", 42
question, answer = ("meaning of life", 42)
# Out:
# 'meaning of life'

# %%
Waynes_boss = "Bruce Wayne"

# %%
Batman = Waynes_boss

# %%
id(Batman) == id(Waynes_boss)
# Out:
# True

# %%
Batman is Waynes_boss
# Out:
# True

# %%
my_helo = "Bruce Wayne"

# %%
my_helo is Batman
# Out:
# False

# %%
i = 42
j = i

# %%
i is j
# Out:
# True

# %%
k = 42

# %%
i is k
# Out:
# True

# %%
del Batman[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 del Batman[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
id(k)
# Out:
# 4398884256

# %%
count = 42

# %%
print(f"{count * 2=}")
# Out:
# count * 2=84

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
wizards = ['Merlin', 'Tim']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
wizards = ['Merlin', 'Tim']

for peon in camelot:
    print(peon)
    if peon in wizards:
        print('You have a wizard')
        break
else:
    print("You NEED a wizard")
# Out:
# Arthur
# Merlin
# Lancelot
# Robin
# Perceval
# Karadoc
# You NEED a wizard

# %%
knights_count = {"camelot":4}

# %%
knights_count["camelot"]+= 1

# %%
knights_count["Westeros"] = knights_count.get("Westeros", 0) + 1

# %%
knights_count
# Out:
# {'camelot': 5, 'Westeros': 1}

# %%
def addvalue(counter:dict, item):
    try:
        counter[item] += 1
    except KeyError:
        counter[item] = 1

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[1:4]
# Out:
# ['Merlin', 'Lancelot', 'Robin']

# %%
camelot[:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[-2:]
# Out:
# ['Perceval', 'Karadoc']

# %%
camelot[::2]
# Out:
# ['Arthur', 'Lancelot', 'Perceval']

# %%
camelot[0:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[2:4]
# Out:
# ['Lancelot', 'Robin']

# %%
camelot[40:100]
# Out:
# []

# %%
start = 0
step = 2


while guards := camelot[start:start + step]:
    print(guards)
    start += step
# Out:
# ['Arthur', 'Merlin']
# ['Lancelot', 'Robin']
# ['Perceval', 'Karadoc']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
camelot[1:2] = ["John", "Conan"]
camelot
# Out:
# ['Arthur', 'John', 'Conan', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot
# Out:
# ['Arthur', 'John', 'Conan', 'Perceval', 'Karadoc']

# %%
s = slice(1, 4)

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
camelot[s]
# Out:
# ['Merlin', 'Lancelot', 'Robin']
